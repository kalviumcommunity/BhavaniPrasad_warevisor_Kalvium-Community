# %% [markdown]
# # Funnel Analysis & Drop-Off Detection
#
# This notebook runs the funnel workflow used for the assignment and saves the chart and text report into the `output/` folder.

# %%
from scripts.funnel_analysis import run_pipeline

artifacts = run_pipeline()
artifacts.stages

# %%
artifacts.funnel_df

# %%
artifacts.impact_df

# %%
print(artifacts.recommendation)

# %% [markdown]
# ## Outputs
#
# - `output/funnel_chart.png`
# - `output/funnel_analysis.txt`
