# %% [markdown]
# # Duplicate Detection and Null-Row Removal Worklog
#
# This notebook captures what was completed in the warehouse retail dataset cleanup workflow:
#
# 1. Exact duplicate detection
# 2. Near-duplicate detection by business keys
# 3. Null-value row removal
# 4. Audit logging of removed records
# 5. Before/after metric comparison

# %% [markdown]
# ## Inspect Removed Rows
#
# The audit file contains the exact rows removed from the original dataset.

# %% [markdown]
# ## What Was Achieved
#
# - Duplicate logic was executed on the warehouse dataset.
# - Null-value rows were removed before final save.
# - Full audit artifacts were generated for traceability.
# - Cleaned output was written to `data/processed/warehouse_retail_sales_cleaned.csv`.
